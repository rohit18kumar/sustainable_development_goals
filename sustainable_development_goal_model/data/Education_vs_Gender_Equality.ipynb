# %%
import pandas as pd
import numpy as np
from scipy.stats import norm,pearsonr
import io
from scipy import stats

# %%
df=pd.read_csv('Education and gender equality.csv')
df=df.loc[0:35]
df
# Out:
#     S.no.         Category                                  State/UT  \
# 0     1.0            State                            Andhra Pradesh
# 1     2.0            State                         Arunachal Pradesh
# 2     3.0            State                                     Assam
# 3     4.0            State                                     Bihar
# 4     5.0            State                              Chhattisgarh
# 5     6.0            State                                       Goa
# 6     7.0            State                                   Gujarat
# 7     8.0            State                                   Haryana
# 8     9.0            State                          Himachal Pradesh
# 9    10.0            State                                 Jharkhand
# 10   11.0            State                                 Karnataka
# 11   12.0            State                                    Kerala
# 12   13.0            State                            Madhya Pradesh
# ...

# %%
mean = 48

# %%
df = df.sort_values('Education',ascending = False)
new_df =df.head(5)
new_df
# Out:
#     S.no.         Category          State/UT  Unnamed: 3  Education  \
# 11   12.0            State            Kerala         NaN       80.0
# 29   30.0  Union Territory        Chandigarh         NaN       79.0
# 31   32.0  Union Territory             Delhi         NaN       75.0
# 8     9.0            State  Himachal Pradesh         NaN       74.0
# 5     6.0            State               Goa         NaN       71.0
#
#     Gender Equality
# 11             63.0
# 29             58.0
# 31             33.0
# 8              62.0
# 5              55.0

# %%
import scipy
GndEq=df['Gender Equality']
t_value,p_value = scipy.stats.ttest_1samp(GndEq,mean,alternative='greater')
print('Test statistic is %f'%float("{:.6f}".format(t_value)))

print('p-value for one tailed test is %f'%p_value)
# Out:
# Test statistic is 1.310946
# p-value for one tailed test is 0.099206

# %%
import scipy
GndEq=df['Gender Equality']
t_value,p_value = scipy.stats.ttest_1samp(GndEq,mean,alternative='less')
print('Test statistic is %f'%float("{:.6f}".format(t_value)))

print('p-value for one tailed test is %f'%p_value)
# Out:
# Test statistic is 1.310946
# p-value for one tailed test is 0.900794
