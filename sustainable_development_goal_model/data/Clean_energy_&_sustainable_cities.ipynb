# %%
import pandas as pd
import numpy as np
from scipy.stats import norm,pearsonr
import io
from scipy import stats

# %%
df=pd.read_csv('Clean energy and sustainable citties.csv')
del df['S.no.'],df['State/UT'],df['Unnamed: 3']
df=df.loc[0:35]
df
# Out:
#            Category  Clean energy  Sustainable cities
# 0             State           100                  78
# 1             State            85                  39
# 2             State            98                  55
# 3             State            78                  67
# 4             State            78                  78
# 5             State           100                  89
# 6             State            94                  87
# 7             State           100                  81
# 8             State           100                  79
# 9             State            77                  71
# 10            State           100                  78
# 11            State           100                  75
# 12            State            86                  81
# 13            State           100                  87
# 14            State            96                  65
# 15            State            50                  51
# ...

# %%
mean = 79

# %%
df = df.sort_values('Clean energy',ascending = False)
new_df =df.head(5)
new_df
# Out:
#    Category  Clean energy  Sustainable cities
# 0     State           100                  78
# 21    State           100                  85
# 19    State           100                  91
# 22    State           100                  79
# 23    State           100                  76

# %%
GndEq=df['Sustainable cities']
t_value,p_value = ttest_1samp(GndEq,mean,alternative='greater')
print('Test statistic is %f'%float("{:.6f}".format(t_value)))

print('p-value for one tailed test is %f'%p_value)
# Out:
# Test statistic is -2.868156
# p-value for one tailed test is 0.996525

# %%
GndEq=df['Sustainable cities']
t_value,p_value = ttest_1samp(GndEq,mean,alternative='less')
print('Test statistic is %f'%float("{:.6f}".format(t_value)))

print('p-value for one tailed test is %f'%p_value)
# Out:
# Test statistic is -2.868156
# p-value for one tailed test is 0.003475
